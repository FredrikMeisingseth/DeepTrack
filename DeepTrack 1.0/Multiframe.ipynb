# %%
import filmGeneration

# %% [markdown]
# ## Test film generation

# %%
from matplotlib import pyplot as plt

batch = filmGeneration.get_batch(batch_size = 50)
for i in range(5):
    plt.imshow(batch[0][i,:,:,0], cmap = 'gray')
    plt.show()
# Out:
# Pixel_x is: 152. Pixel_y is: 92.
# Pixel_x is: 152. Pixel_y is: 93.
# Pixel_x is: 152. Pixel_y is: 94.
# Pixel_x is: 152. Pixel_y is: 95.
# Pixel_x is: 153. Pixel_y is: 92.
# Pixel_x is: 153. Pixel_y is: 93.
# Pixel_x is: 153. Pixel_y is: 94.
# Pixel_x is: 153. Pixel_y is: 95.
# Pixel_x is: 154. Pixel_y is: 92.
# Pixel_x is: 154. Pixel_y is: 93.
# Pixel_x is: 154. Pixel_y is: 94.
# Pixel_x is: 154. Pixel_y is: 95.
# Pixel_x is: 155. Pixel_y is: 92.
# Pixel_x is: 155. Pixel_y is: 93.
# Pixel_x is: 155. Pixel_y is: 94.
# Pixel_x is: 155. Pixel_y is: 95.
# Pixel_x is: 130. Pixel_y is: 250.
# Pixel_x is: 131. Pixel_y is: 249.
# Pixel_x is: 131. Pixel_y is: 250.
# Pixel_x is: 131. Pixel_y is: 251.
# Pixel_x is: 132. Pixel_y is: 250.
# Pixel_x is: 140. Pixel_y is: 119.
# Pixel_x is: 140. Pixel_y is: 120.
# Pixel_x is: 140. Pixel_y is: 121.
# Pixel_x is: 141. Pixel_y is: 119.
# Pixel_x is: 141. Pixel_y is: 120.
# Pixel_x is: 141. Pixel_y is: 121.
# Pixel_x is: 112. Pixel_y is: 201.
# ...
