# %%
import imageGeneration, deeptrack
import cv2
import numpy as np
from matplotlib import pyplot as plt

image_parameters = imageGeneration.get_image_parameters_preconfig()

image = imageGeneration.get_image(image_parameters)
label = imageGeneration.get_label(image_parameters)
print(image.shape)
print(label.shape)
plt.imshow(image, cmap = 'gray')
plt.colorbar()

#for x in range(label.shape[0])
#    for y in range(label.shape[1])
#        plt.quiver()
# Out:
# (128, 128)
# (128, 128, 5)

# %%
plt.imshow(label[:,:,0], cmap = 'gray')
plt.colorbar()

# %%
plt.imshow(label[:,:,3], cmap = 'gray')
plt.colorbar()
